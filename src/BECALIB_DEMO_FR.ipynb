# %% [markdown]
# ![logo_big.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# [github repo](https://github.com/SimoneAragno/becalib)

# %% [markdown]
# ## Installation
# intallation pour google colab:

# %%
# !pip install -i https://test.pypi.org/simple/ becalib

# %% [markdown]
# ## Import des classes et methodes BECALIB

# %%
from becalib.layers import MaterialLayer, AirLayer
from becalib.component import Component

# %% [markdown]
# ## Definition des couches de la parois
# Créer les couches de la parois et definir les paramètres thermiques.

# %%
beton  =  MaterialLayer(
            name="Béton",
            thickness=0.1, # m
            thermal_conductivity=1.8, # lambda W/mK
            specific_heat_capacity=1000, #  c J/kgK
            gross_density=2400, # ro kg/mc
        )

couche_air  =  AirLayer(
    name="Couche d'air",
    thickness=0.1, # m
    heat_flow_direction="Do"

)

monomur  =  MaterialLayer(
    name="Monomur",
    thickness=0.08, # m
    thermal_conductivity=0.35, # lambda W/mK
    specific_heat_capacity=840, #  c J/kgK
    gross_density=750, # ro kg/mc

)

brique  =  MaterialLayer(
    name="Brique",
    thickness=0.12, # m
    thermal_conductivity=0.8, # lambda W/mK
    specific_heat_capacity=840, #  c J/kgK
    gross_density=1800, # ro kg/mc

)
isolant  =  MaterialLayer(
    name="Isolant",
    thickness=0.05, # m
    thermal_conductivity=0.035, # lambda W/mK
    specific_heat_capacity=840, #  c J/kgK
    gross_density=175, # ro kg/mc
)

enduit  =  MaterialLayer(
    name="Enduit",
    thickness=0.02, # m
    thermal_conductivity=0.9, # lambda W/mK
    specific_heat_capacity=840, # calore spec c J/kgK
    gross_density=1400, # ro kg/mc
)

# %% [markdown]
# ## Definition de la paroi
# * liste des couches de l'interieur vers l'exterieur
# * direction du flux de chaleur: \
#     "Ho": Horizontal (mur) or \
#     "Up": Upwards (toit) or \
#     "Do": Downwards (plancher bas)
# * language: en, fr, etc...

# %%
paroi = Component(name="Paroi",
                layers=[
                beton,
                couche_air,
                monomur,
                brique,
                isolant,
                enduit ],
                heat_flow_direction="Ho",
                language="fr"
                )

# %% [markdown]
# ## Tableau des couches (pandas DataFrame)

# %%
paroi.get_layers_dataframe(data_type="st")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8691e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8691e_level0_col0" class="col_heading level0 col0" >Nom</th>
#       <th id="T_8691e_level0_col1" class="col_heading level0 col1" >Épaisseur [m]</th>
#       <th id="T_8691e_level0_col2" class="col_heading level0 col2" >Conductivité thermique λ</th>
#       <th id="T_8691e_level0_col3" class="col_heading level0 col3" >Résistance R [m²K/W]</th>
#       <th id="T_8691e_level0_col4" class="col_heading level0 col4" >is_air</th>
#       <th id="T_8691e_level0_col5" class="col_heading level0 col5" >Densité ρ [kg/m³]</th>
#       <th id="T_8691e_level0_col6" class="col_heading level0 col6" >Capacité thermique massique  c [J/kgK]</th>
#       <th id="T_8691e_level0_col7" class="col_heading level0 col7" >Diffusivite α [m²/ (s*10^6)]</th>
#       <th id="T_8691e_level0_col8" class="col_heading level0 col8" >Effusivité</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8691e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8691e_row0_col0" class="data row0 col0" >Surface intérieure</td>
#       <td id="T_8691e_row0_col1" class="data row0 col1" ></td>
#       <td id="T_8691e_row0_col2" class="data row0 col2" ></td>
#       <td id="T_8691e_row0_col3" class="data row0 col3" >0.130</td>
#       <td id="T_8691e_row0_col4" class="data row0 col4" ></td>
#       <td id="T_8691e_row0_col5" class="data row0 col5" ></td>
#       <td id="T_8691e_row0_col6" class="data row0 col6" ></td>
#       <td id="T_8691e_row0_col7" class="data row0 col7" ></td>
#       <td id="T_8691e_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_8691e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8691e_row1_col0" class="data row1 col0" >Béton</td>
#       <td id="T_8691e_row1_col1" class="data row1 col1" >0.10</td>
#       <td id="T_8691e_row1_col2" class="data row1 col2" >1.800</td>
#       <td id="T_8691e_row1_col3" class="data row1 col3" >0.056</td>
#       <td id="T_8691e_row1_col4" class="data row1 col4" >False</td>
#       <td id="T_8691e_row1_col5" class="data row1 col5" >2400</td>
#       <td id="T_8691e_row1_col6" class="data row1 col6" >1000</td>
#       <td id="T_8691e_row1_col7" class="data row1 col7" >0.750</td>
#       <td id="T_8691e_row1_col8" class="data row1 col8" >2078.5</td>
#     </tr>
#     <tr>
#       <th id="T_8691e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8691e_row2_col0" class="data row2 col0" >Couche d'air</td>
#       <td id="T_8691e_row2_col1" class="data row2 col1" >0.10</td>
#       <td id="T_8691e_row2_col2" class="data row2 col2" ></td>
#       <td id="T_8691e_row2_col3" class="data row2 col3" >0.180</td>
#       <td id="T_8691e_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_8691e_row2_col5" class="data row2 col5" ></td>
#       <td id="T_8691e_row2_col6" class="data row2 col6" ></td>
#       <td id="T_8691e_row2_col7" class="data row2 col7" ></td>
#       <td id="T_8691e_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_8691e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8691e_row3_col0" class="data row3 col0" >Monomur</td>
#       <td id="T_8691e_row3_col1" class="data row3 col1" >0.08</td>
#       <td id="T_8691e_row3_col2" class="data row3 col2" >0.350</td>
#       <td id="T_8691e_row3_col3" class="data row3 col3" >0.229</td>
#       <td id="T_8691e_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_8691e_row3_col5" class="data row3 col5" >750</td>
#       <td id="T_8691e_row3_col6" class="data row3 col6" >840</td>
#       <td id="T_8691e_row3_col7" class="data row3 col7" >0.556</td>
#       <td id="T_8691e_row3_col8" class="data row3 col8" >469.6</td>
#     </tr>
#     <tr>
#       <th id="T_8691e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8691e_row4_col0" class="data row4 col0" >Brique</td>
#       <td id="T_8691e_row4_col1" class="data row4 col1" >0.12</td>
#       <td id="T_8691e_row4_col2" class="data row4 col2" >0.800</td>
#       <td id="T_8691e_row4_col3" class="data row4 col3" >0.150</td>
#       <td id="T_8691e_row4_col4" class="data row4 col4" >False</td>
#       <td id="T_8691e_row4_col5" class="data row4 col5" >1800</td>
#       <td id="T_8691e_row4_col6" class="data row4 col6" >840</td>
#       <td id="T_8691e_row4_col7" class="data row4 col7" >0.529</td>
#       <td id="T_8691e_row4_col8" class="data row4 col8" >1099.8</td>
#     </tr>
#     <tr>
#       <th id="T_8691e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8691e_row5_col0" class="data row5 col0" >Isolant</td>
#       <td id="T_8691e_row5_col1" class="data row5 col1" >0.05</td>
#       <td id="T_8691e_row5_col2" class="data row5 col2" >0.035</td>
#       <td id="T_8691e_row5_col3" class="data row5 col3" >1.429</td>
#       <td id="T_8691e_row5_col4" class="data row5 col4" >False</td>
#       <td id="T_8691e_row5_col5" class="data row5 col5" >175</td>
#       <td id="T_8691e_row5_col6" class="data row5 col6" >840</td>
#       <td id="T_8691e_row5_col7" class="data row5 col7" >0.238</td>
#       <td id="T_8691e_row5_col8" class="data row5 col8" >71.7</td>
#     </tr>
#     <tr>
#       <th id="T_8691e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8691e_row6_col0" class="data row6 col0" >Enduit</td>
#       <td id="T_8691e_row6_col1" class="data row6 col1" >0.02</td>
#       <td id="T_8691e_row6_col2" class="data row6 col2" >0.900</td>
#       <td id="T_8691e_row6_col3" class="data row6 col3" >0.022</td>
#       <td id="T_8691e_row6_col4" class="data row6 col4" >False</td>
#       <td id="T_8691e_row6_col5" class="data row6 col5" >1400</td>
#       <td id="T_8691e_row6_col6" class="data row6 col6" >840</td>
#       <td id="T_8691e_row6_col7" class="data row6 col7" >0.765</td>
#       <td id="T_8691e_row6_col8" class="data row6 col8" >1028.8</td>
#     </tr>
#     <tr>
#       <th id="T_8691e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8691e_row7_col0" class="data row7 col0" >Surface extérieure</td>
#       <td id="T_8691e_row7_col1" class="data row7 col1" ></td>
#       <td id="T_8691e_row7_col2" class="data row7 col2" ></td>
#       <td id="T_8691e_row7_col3" class="data row7 col3" >0.040</td>
#       <td id="T_8691e_row7_col4" class="data row7 col4" ></td>
#       <td id="T_8691e_row7_col5" class="data row7 col5" ></td>
#       <td id="T_8691e_row7_col6" class="data row7 col6" ></td>
#       <td id="T_8691e_row7_col7" class="data row7 col7" ></td>
#       <td id="T_8691e_row7_col8" class="data row7 col8" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Imprimer les valeurs calculées

# %%
print(paroi.get_summer_performance_key_values())
# Out:
# #######################################
# Composant: Paroi
#
# Période : 24 [h]
#
# Épaisseur: 0.470 [m]
# Résistance: 2.235 [m²K/W] Rsi and Rse included
# Conductivité thermique (U-value W/m²K): 0.447 [W/m²K]
#
# Facteur d'ammortissement: 0.060 [-]
# Déphasage: 13.4 [h]
#
# Capacité thermique surfacique intérieure: 82.966 [kJ/m²K]
#
# Performance d'été: Excellent 5/5 (in accordance with italian DM 26/06/2009)
# Masse surfacique: 552.8 [kg/m²]
#
# #######################################

# %% [markdown]
# ## Imprimer les graphiques

# %%
paroi.get_component_layers_chart().show()

# %%
paroi.get_component_sinusoidal_wave_chart().show()
